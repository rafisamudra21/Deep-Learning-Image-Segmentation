# %% [markdown]
# **Project Tesis Muhammad Azhar Rafi' Samudra**

# %% [markdown]
# ## **Building Mapping**
#
# In project, we are going to detect the buildings using satellite imagery. It is a binary class segmentation problem.
#
#
# ### **Dataset**
# The dataset is taken from Badan Informasi Geospasial (BIG) and restricted use.
#
# Input data are RGB satellite images. And output are binary images. Pixel value is 0 for non-buildings and pixel value is 1 for buildings.

# %%
# import necessary libraries
import glob
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

from PIL import Image

from tensorflow.python.keras import Model
from tensorflow.python.keras.layers import Input, Conv2D, MaxPooling2D, Conv2DTranspose, Concatenate, Dropout
# Out:
# D:\Anaconda\lib\site-packages\scipy\__init__.py:155: UserWarning: A NumPy version >=1.18.5 and <1.25.0 is required for this version of SciPy (detected version 1.26.4
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
# !pip install tensorflow==2.20.0
# Out:
# Requirement already satisfied: tensorflow==2.20.0 in d:\anaconda\lib\site-packages (2.20.0)
# Requirement already satisfied: absl-py>=1.0.0 in d:\anaconda\lib\site-packages (from tensorflow==2.20.0) (2.3.1)
# Requirement already satisfied: astunparse>=1.6.0 in d:\anaconda\lib\site-packages (from tensorflow==2.20.0) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in d:\anaconda\lib\site-packages (from tensorflow==2.20.0) (25.9.23)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in d:\anaconda\lib\site-packages (from tensorflow==2.20.0) (0.6.0)
# Requirement already satisfied: google_pasta>=0.1.1 in d:\anaconda\lib\site-packages (from tensorflow==2.20.0) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in d:\anaconda\lib\site-packages (from tensorflow==2.20.0) (18.1.1)
# Requirement already satisfied: opt_einsum>=2.3.2 in d:\anaconda\lib\site-packages (from tensorflow==2.20.0) (3.4.0)
# Requirement already satisfied: packaging in d:\anaconda\lib\site-packages (from tensorflow==2.20.0) (21.3)
# Requirement already satisfied: protobuf>=5.28.0 in d:\anaconda\lib\site-packages (from tensorflow==2.20.0) (6.33.0)
# Requirement already satisfied: requests<3,>=2.21.0 in d:\anaconda\lib\site-packages (from tensorflow==2.20.0) (2.28.1)
# Requirement already satisfied: setuptools in d:\anaconda\lib\site-packages (from tensorflow==2.20.0) (63.4.1)
# Requirement already satisfied: six>=1.12.0 in d:\anaconda\lib\site-packages (from tensorflow==2.20.0) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in d:\anaconda\lib\site-packages (from tensorflow==2.20.0) (3.1.0)
# Requirement already satisfied: typing_extensions>=3.6.6 in d:\anaconda\lib\site-packages (from tensorflow==2.20.0) (4.15.0)
# Requirement already satisfied: wrapt>=1.11.0 in d:\anaconda\lib\site-packages (from tensorflow==2.20.0) (1.14.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in d:\anaconda\lib\site-packages (from tensorflow==2.20.0) (1.76.0)
# Requirement already satisfied: tensorboard~=2.20.0 in d:\anaconda\lib\site-packages (from tensorflow==2.20.0) (2.20.0)
# Requirement already satisfied: keras>=3.10.0 in d:\anaconda\lib\site-packages (from tensorflow==2.20.0) (3.10.0)
# Requirement already satisfied: numpy>=1.26.0 in d:\anaconda\lib\site-packages (from tensorflow==2.20.0) (1.26.4)
# Requirement already satisfied: h5py>=3.11.0 in d:\anaconda\lib\site-packages (from tensorflow==2.20.0) (3.14.0)
# Requirement already satisfied: ml_dtypes<1.0.0,>=0.5.1 in d:\anaconda\lib\site-packages (from tensorflow==2.20.0) (0.5.3)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in d:\anaconda\lib\site-packages (from astunparse>=1.6.0->tensorflow==2.20.0) (0.37.1)
# Requirement already satisfied: rich in d:\anaconda\lib\site-packages (from keras>=3.10.0->tensorflow==2.20.0) (14.2.0)
# Requirement already satisfied: namex in d:\anaconda\lib\site-packages (from keras>=3.10.0->tensorflow==2.20.0) (0.1.0)
# Requirement already satisfied: optree in d:\anaconda\lib\site-packages (from keras>=3.10.0->tensorflow==2.20.0) (0.17.0)
# Requirement already satisfied: charset-normalizer<3,>=2 in d:\anaconda\lib\site-packages (from requests<3,>=2.21.0->tensorflow==2.20.0) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in d:\anaconda\lib\site-packages (from requests<3,>=2.21.0->tensorflow==2.20.0) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in d:\anaconda\lib\site-packages (from requests<3,>=2.21.0->tensorflow==2.20.0) (1.26.11)
# Requirement already satisfied: certifi>=2017.4.17 in d:\anaconda\lib\site-packages (from requests<3,>=2.21.0->tensorflow==2.20.0) (2022.9.14)
# Requirement already satisfied: markdown>=2.6.8 in d:\anaconda\lib\site-packages (from tensorboard~=2.20.0->tensorflow==2.20.0) (3.3.4)
# Requirement already satisfied: pillow in d:\anaconda\lib\site-packages (from tensorboard~=2.20.0->tensorflow==2.20.0) (9.2.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in d:\anaconda\lib\site-packages (from tensorboard~=2.20.0->tensorflow==2.20.0) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in d:\anaconda\lib\site-packages (from tensorboard~=2.20.0->tensorflow==2.20.0) (2.0.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in d:\anaconda\lib\site-packages (from packaging->tensorflow==2.20.0) (3.0.9)
# Requirement already satisfied: markdown-it-py>=2.2.0 in d:\anaconda\lib\site-packages (from rich->keras>=3.10.0->tensorflow==2.20.0) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in d:\anaconda\lib\site-packages (from rich->keras>=3.10.0->tensorflow==2.20.0) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in d:\anaconda\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.10.0->tensorflow==2.20.0) (0.1.2)
# [notice] A new release of pip is available: 24.0 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import os

os.chdir(r"D:\Kuliah\Magister\Tesis\Percobaan\CBAM3")
print(os.getcwd())
# Out:
# D:\Kuliah\Magister\Tesis\Percobaan\CBAM3

# %%
import os

files = os.listdir(r"D:\Kuliah\Magister\Tesis\Percobaan\CBAM3")
files
# Out:
# ['test', 'train']

# %%
# set the working directory
import os
os.chdir(r"D:\Kuliah\Magister\Tesis\Percobaan\CBAM3")

# %% [markdown]
# ## **Data Pre-Processing**

# %%
train_x = sorted(glob.glob('train/*_image.tif'))
train_y = sorted(glob.glob('train/*_label.tif'))
test_x = sorted(glob.glob('test/*_image.tif'))
test_y = sorted(glob.glob('test/*_label.tif'))

print(len(train_x), len(train_y), len(test_x), len(test_y))
# Out:
# 2414 2414 80 80

# %%
# Converting training image to numpy array
train_xx = np.zeros((2414, 128, 128, 3))
train_yy = np.zeros((2414, 128, 128, 1))
for i, (img, mask) in enumerate(zip(train_x, train_y)):
  # if i == 1:
  #   break

  img = Image.open(img)
  np_img = np.array(img)
  train_xx[i] = np_img

  mask = Image.open(mask)
  np_mask = np.array(mask).reshape(128, 128, 1)
  train_yy[i] = np_mask

# %%
# Converting testing image to numpy array
test_xx = np.zeros((80, 128, 128, 3))
test_yy = np.zeros((80, 128, 128, 1))
for i, (img, mask) in enumerate(zip(test_x, test_y)):

  img = Image.open(img)
  np_img = np.array(img)
  test_xx[i] = np_img

  mask = Image.open(mask)
  np_mask = np.array(mask).reshape(128, 128, 1)
  test_yy[i] = np_mask

# %%
# Plot a sample input RGB image and output image with buildings

plt.imshow(train_xx[200, :, :, :].astype('uint8'))
plt.show()
plt.imshow(train_yy[200, :, :, 0].astype('uint8'))
plt.show()

# %% [markdown]
# ## **Save to numpy format**

# %%
train_xx.shape
# Out:
# (2414, 128, 128, 3)

# %%
np.save('train_xx.npy', train_xx)
np.save('train_yy.npy', train_yy)
np.save("test_xx.npy", test_xx)
np.save("test_yy.npy", test_yy)

# %%
# Load file numpy
train_xx = np.load('train_xx.npy')
train_yy = np.load('train_yy.npy')
test_xx  = np.load('test_xx.npy')
test_yy  = np.load('test_yy.npy')

# Cek bentuk data (opsional)
print("train_xx shape:", train_xx.shape)
print("train_yy shape:", train_yy.shape)
print("test_xx shape :", test_xx.shape)
print("test_yy shape :", test_yy.shape)
# Out:
# train_xx shape: (2414, 128, 128, 3)
# train_yy shape: (2414, 128, 128, 1)
# test_xx shape : (80, 128, 128, 3)
# test_yy shape : (80, 128, 128, 1)

# %% [markdown]
# # **CBAM-UNet model development**
#
#
#
# ![image.png](data:image/png;base64,...)

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.layers import (
    Input, Conv2D, Conv2DTranspose, MaxPooling2D, Dropout, Concatenate,
    GlobalAveragePooling2D, GlobalMaxPooling2D, Reshape, Dense, Multiply,
    Add, Activation, Lambda, BatchNormalization
)
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
import tensorflow as tf
from tensorflow.keras.saving import register_keras_serializable

@register_keras_serializable()
def reduce_mean_spatial(x):
    return tf.reduce_mean(x, axis=3, keepdims=True)

@register_keras_serializable()
def reduce_max_spatial(x):
    return tf.reduce_max(x, axis=3, keepdims=True)


def cbam_block(input_feature, ratio=8):
    """CBAM: Channel Attention + Spatial Attention"""

    channel = int(input_feature.shape[-1])

    shared_dense_one = Dense(channel // ratio,
                             activation='relu',
                             kernel_initializer='he_normal',
                             use_bias=True)

    shared_dense_two = Dense(channel,
                             kernel_initializer='he_normal',
                             use_bias=True)

    # ---- Channel Attention ----
    avg_pool = GlobalAveragePooling2D()(input_feature)
    avg_pool = Reshape((1,1,channel))(avg_pool)
    avg_pool = shared_dense_one(avg_pool)
    avg_pool = shared_dense_two(avg_pool)

    max_pool = GlobalMaxPooling2D()(input_feature)
    max_pool = Reshape((1,1,channel))(max_pool)
    max_pool = shared_dense_one(max_pool)
    max_pool = shared_dense_two(max_pool)

    channel_attention = Add()([avg_pool, max_pool])
    channel_attention = Activation('sigmoid')(channel_attention)

    channel_refined = Multiply()([input_feature, channel_attention])

    # ---- Spatial Attention ----
    avg_pool_spatial = Lambda(reduce_mean_spatial)(channel_refined)
    max_pool_spatial = Lambda(reduce_max_spatial)(channel_refined)

    concat_spatial = Concatenate(axis=3)([avg_pool_spatial, max_pool_spatial])

    spatial_attention = Conv2D(filters=1,
                               kernel_size=(7,7),
                               strides=1,
                               padding='same',
                               activation='sigmoid',
                               kernel_initializer='he_normal')(concat_spatial)

    refined_feature = Multiply()([channel_refined, spatial_attention])

    return refined_feature


# ================= Model Architecture =================

x_in = Input(shape=(128, 128, 3))

# Encoder
x_temp = Conv2D(32, (3, 3), activation='relu', padding='same')(x_in)
x_temp = BatchNormalization()(x_temp)
x_temp = Dropout(0.25)(x_temp)
x_skip1 = Conv2D(32, (3, 3), activation='relu', padding='same')(x_temp)
x_skip1 = BatchNormalization()(x_skip1)
x_skip1 = cbam_block(x_skip1, ratio=8)

x_temp = MaxPooling2D((2,2))(x_skip1)
x_temp = Conv2D(32, (3, 3), activation='relu', padding='same')(x_temp)
x_temp = BatchNormalization()(x_temp)
x_temp = Dropout(0.25)(x_temp)
x_skip2 = Conv2D(32, (3, 3), activation='relu', padding='same')(x_temp)
x_skip2 = BatchNormalization()(x_skip2)
x_skip2 = cbam_block(x_skip2, ratio=8)

x_temp = MaxPooling2D((2,2))(x_skip2)
x_temp = Conv2D(64, (3, 3), activation='relu', padding='same')(x_temp)
x_temp = BatchNormalization()(x_temp)
x_temp = Dropout(0.25)(x_temp)
x_skip3 = Conv2D(64, (3, 3), activation='relu', padding='same')(x_temp)
x_skip3 = BatchNormalization()(x_skip3)
x_skip3 = cbam_block(x_skip3, ratio=8)

x_temp = MaxPooling2D((2,2))(x_skip3)
x_temp = Conv2D(64, (3, 3), activation='relu', padding='same')(x_temp)
x_temp = BatchNormalization()(x_temp)
x_temp = Dropout(0.5)(x_temp)
x_temp = Conv2D(64, (3, 3), activation='relu', padding='same')(x_temp)
x_temp = BatchNormalization()(x_temp)

# Decoder
x_temp = Conv2DTranspose(64, (3, 3), activation='relu', padding='same')(x_temp)
x_temp = BatchNormalization()(x_temp)
x_temp = Dropout(0.5)(x_temp)
x_temp = Conv2DTranspose(64, (3, 3), strides=(2, 2), activation='relu', padding='same')(x_temp)
x_temp = BatchNormalization()(x_temp)

x_temp = Concatenate()([x_temp, x_skip3])
x_temp = cbam_block(x_temp, ratio=8)

x_temp = Conv2DTranspose(64, (3, 3), activation='relu', padding='same')(x_temp)
x_temp = BatchNormalization()(x_temp)
x_temp = Dropout(0.5)(x_temp)
x_temp = Conv2DTranspose(64, (3, 3), strides=(2, 2), activation='relu', padding='same')(x_temp)
x_temp = BatchNormalization()(x_temp)

x_temp = Concatenate()([x_temp, x_skip2])
x_temp = cbam_block(x_temp, ratio=8)

x_temp = Conv2DTranspose(32, (3, 3), activation='relu', padding='same')(x_temp)
x_temp = BatchNormalization()(x_temp)
x_temp = Dropout(0.5)(x_temp)
x_temp = Conv2DTranspose(32, (3, 3), strides=(2, 2), activation='relu', padding='same')(x_temp)
x_temp = BatchNormalization()(x_temp)

x_temp = Concatenate()([x_temp, x_skip1])
x_temp = cbam_block(x_temp, ratio=8)

x_temp = Conv2DTranspose(32, (3, 3), activation='relu', padding='same')(x_temp)
x_temp = BatchNormalization()(x_temp)
x_temp = Dropout(0.5)(x_temp)
x_temp = Conv2DTranspose(32, (3, 3), activation='relu', padding='same')(x_temp)
x_temp = BatchNormalization()(x_temp)

# Output
x_temp = Conv2D(32, (1, 1), activation='relu', padding='same')(x_temp)
x_temp = BatchNormalization()(x_temp)
x_temp = Conv2D(32, (1, 1), activation='relu', padding='same')(x_temp)
x_temp = BatchNormalization()(x_temp)

x_out = Conv2D(1, (1, 1), activation='sigmoid', padding='same')(x_temp)

model = Model(inputs=x_in, outputs=x_out)
model.compile(loss='mean_squared_error', optimizer='adam', metrics=['accuracy'])

model.summary()
# Out:
# WARNING:tensorflow:From D:\Anaconda\lib\site-packages\keras\src\backend\tensorflow\core.py:232: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                  ┃ Output Shape              ┃         Param # ┃ Connected to               ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)      │ (None, 128, 128, 3)       │               0 │ -                          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d (Conv2D)               │ (None, 128, 128, 32)      │             896 │ input_layer[0][0]          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization           │ (None, 128, 128, 32)      │             128 │ conv2d[0][0]               │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dropout (Dropout)             │ (None, 128, 128, 32)      │               0 │ batch_normalization[0][0]  │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_1 (Conv2D)             │ (None, 128, 128, 32)      │           9,248 │ dropout[0][0]              │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_1         │ (None, 128, 128, 32)      │             128 │ conv2d_1[0][0]             │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ global_average_pooling2d      │ (None, 32)                │               0 │ batch_normalization_1[0][… │
# │ (GlobalAveragePooling2D)      │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ global_max_pooling2d          │ (None, 32)                │               0 │ batch_normalization_1[0][… │
# │ (GlobalMaxPooling2D)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ reshape (Reshape)             │ (None, 1, 1, 32)          │               0 │ global_average_pooling2d[… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ reshape_1 (Reshape)           │ (None, 1, 1, 32)          │               0 │ global_max_pooling2d[0][0] │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense (Dense)                 │ (None, 1, 1, 4)           │             132 │ reshape[0][0],             │
# │                               │                           │                 │ reshape_1[0][0]            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense_1 (Dense)               │ (None, 1, 1, 32)          │             160 │ dense[0][0], dense[1][0]   │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ add (Add)                     │ (None, 1, 1, 32)          │               0 │ dense_1[0][0],             │
# │                               │                           │                 │ dense_1[1][0]              │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ activation (Activation)       │ (None, 1, 1, 32)          │               0 │ add[0][0]                  │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ multiply (Multiply)           │ (None, 128, 128, 32)      │               0 │ batch_normalization_1[0][… │
# │                               │                           │                 │ activation[0][0]           │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ lambda (Lambda)               │ (None, 128, 128, 1)       │               0 │ multiply[0][0]             │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ lambda_1 (Lambda)             │ (None, 128, 128, 1)       │               0 │ multiply[0][0]             │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ concatenate (Concatenate)     │ (None, 128, 128, 2)       │               0 │ lambda[0][0],              │
# │                               │                           │                 │ lambda_1[0][0]             │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_2 (Conv2D)             │ (None, 128, 128, 1)       │              99 │ concatenate[0][0]          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ multiply_1 (Multiply)         │ (None, 128, 128, 32)      │               0 │ multiply[0][0],            │
# │                               │                           │                 │ conv2d_2[0][0]             │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ max_pooling2d (MaxPooling2D)  │ (None, 64, 64, 32)        │               0 │ multiply_1[0][0]           │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_3 (Conv2D)             │ (None, 64, 64, 32)        │           9,248 │ max_pooling2d[0][0]        │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_2         │ (None, 64, 64, 32)        │             128 │ conv2d_3[0][0]             │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dropout_1 (Dropout)           │ (None, 64, 64, 32)        │               0 │ batch_normalization_2[0][… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_4 (Conv2D)             │ (None, 64, 64, 32)        │           9,248 │ dropout_1[0][0]            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_3         │ (None, 64, 64, 32)        │             128 │ conv2d_4[0][0]             │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ global_average_pooling2d_1    │ (None, 32)                │               0 │ batch_normalization_3[0][… │
# │ (GlobalAveragePooling2D)      │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ global_max_pooling2d_1        │ (None, 32)                │               0 │ batch_normalization_3[0][… │
# │ (GlobalMaxPooling2D)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ reshape_2 (Reshape)           │ (None, 1, 1, 32)          │               0 │ global_average_pooling2d_… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ reshape_3 (Reshape)           │ (None, 1, 1, 32)          │               0 │ global_max_pooling2d_1[0]… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense_2 (Dense)               │ (None, 1, 1, 4)           │             132 │ reshape_2[0][0],           │
# │                               │                           │                 │ reshape_3[0][0]            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense_3 (Dense)               │ (None, 1, 1, 32)          │             160 │ dense_2[0][0],             │
# │                               │                           │                 │ dense_2[1][0]              │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ add_1 (Add)                   │ (None, 1, 1, 32)          │               0 │ dense_3[0][0],             │
# │                               │                           │                 │ dense_3[1][0]              │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ activation_1 (Activation)     │ (None, 1, 1, 32)          │               0 │ add_1[0][0]                │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ multiply_2 (Multiply)         │ (None, 64, 64, 32)        │               0 │ batch_normalization_3[0][… │
# │                               │                           │                 │ activation_1[0][0]         │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ lambda_2 (Lambda)             │ (None, 64, 64, 1)         │               0 │ multiply_2[0][0]           │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ lambda_3 (Lambda)             │ (None, 64, 64, 1)         │               0 │ multiply_2[0][0]           │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ concatenate_1 (Concatenate)   │ (None, 64, 64, 2)         │               0 │ lambda_2[0][0],            │
# │                               │                           │                 │ lambda_3[0][0]             │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_5 (Conv2D)             │ (None, 64, 64, 1)         │              99 │ concatenate_1[0][0]        │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ multiply_3 (Multiply)         │ (None, 64, 64, 32)        │               0 │ multiply_2[0][0],          │
# │                               │                           │                 │ conv2d_5[0][0]             │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ max_pooling2d_1               │ (None, 32, 32, 32)        │               0 │ multiply_3[0][0]           │
# │ (MaxPooling2D)                │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_6 (Conv2D)             │ (None, 32, 32, 64)        │          18,496 │ max_pooling2d_1[0][0]      │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_4         │ (None, 32, 32, 64)        │             256 │ conv2d_6[0][0]             │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dropout_2 (Dropout)           │ (None, 32, 32, 64)        │               0 │ batch_normalization_4[0][… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_7 (Conv2D)             │ (None, 32, 32, 64)        │          36,928 │ dropout_2[0][0]            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_5         │ (None, 32, 32, 64)        │             256 │ conv2d_7[0][0]             │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ global_average_pooling2d_2    │ (None, 64)                │               0 │ batch_normalization_5[0][… │
# │ (GlobalAveragePooling2D)      │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ global_max_pooling2d_2        │ (None, 64)                │               0 │ batch_normalization_5[0][… │
# │ (GlobalMaxPooling2D)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ reshape_4 (Reshape)           │ (None, 1, 1, 64)          │               0 │ global_average_pooling2d_… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ reshape_5 (Reshape)           │ (None, 1, 1, 64)          │               0 │ global_max_pooling2d_2[0]… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense_4 (Dense)               │ (None, 1, 1, 8)           │             520 │ reshape_4[0][0],           │
# │                               │                           │                 │ reshape_5[0][0]            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense_5 (Dense)               │ (None, 1, 1, 64)          │             576 │ dense_4[0][0],             │
# │                               │                           │                 │ dense_4[1][0]              │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ add_2 (Add)                   │ (None, 1, 1, 64)          │               0 │ dense_5[0][0],             │
# │                               │                           │                 │ dense_5[1][0]              │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ activation_2 (Activation)     │ (None, 1, 1, 64)          │               0 │ add_2[0][0]                │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ multiply_4 (Multiply)         │ (None, 32, 32, 64)        │               0 │ batch_normalization_5[0][… │
# │                               │                           │                 │ activation_2[0][0]         │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ lambda_4 (Lambda)             │ (None, 32, 32, 1)         │               0 │ multiply_4[0][0]           │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ lambda_5 (Lambda)             │ (None, 32, 32, 1)         │               0 │ multiply_4[0][0]           │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ concatenate_2 (Concatenate)   │ (None, 32, 32, 2)         │               0 │ lambda_4[0][0],            │
# │                               │                           │                 │ lambda_5[0][0]             │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_8 (Conv2D)             │ (None, 32, 32, 1)         │              99 │ concatenate_2[0][0]        │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ multiply_5 (Multiply)         │ (None, 32, 32, 64)        │               0 │ multiply_4[0][0],          │
# │                               │                           │                 │ conv2d_8[0][0]             │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ max_pooling2d_2               │ (None, 16, 16, 64)        │               0 │ multiply_5[0][0]           │
# │ (MaxPooling2D)                │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_9 (Conv2D)             │ (None, 16, 16, 64)        │          36,928 │ max_pooling2d_2[0][0]      │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_6         │ (None, 16, 16, 64)        │             256 │ conv2d_9[0][0]             │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dropout_3 (Dropout)           │ (None, 16, 16, 64)        │               0 │ batch_normalization_6[0][… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_10 (Conv2D)            │ (None, 16, 16, 64)        │          36,928 │ dropout_3[0][0]            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_7         │ (None, 16, 16, 64)        │             256 │ conv2d_10[0][0]            │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_transpose              │ (None, 16, 16, 64)        │          36,928 │ batch_normalization_7[0][… │
# │ (Conv2DTranspose)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_8         │ (None, 16, 16, 64)        │             256 │ conv2d_transpose[0][0]     │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dropout_4 (Dropout)           │ (None, 16, 16, 64)        │               0 │ batch_normalization_8[0][… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_transpose_1            │ (None, 32, 32, 64)        │          36,928 │ dropout_4[0][0]            │
# │ (Conv2DTranspose)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_9         │ (None, 32, 32, 64)        │             256 │ conv2d_transpose_1[0][0]   │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ concatenate_3 (Concatenate)   │ (None, 32, 32, 128)       │               0 │ batch_normalization_9[0][… │
# │                               │                           │                 │ multiply_5[0][0]           │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ global_average_pooling2d_3    │ (None, 128)               │               0 │ concatenate_3[0][0]        │
# │ (GlobalAveragePooling2D)      │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ global_max_pooling2d_3        │ (None, 128)               │               0 │ concatenate_3[0][0]        │
# │ (GlobalMaxPooling2D)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ reshape_6 (Reshape)           │ (None, 1, 1, 128)         │               0 │ global_average_pooling2d_… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ reshape_7 (Reshape)           │ (None, 1, 1, 128)         │               0 │ global_max_pooling2d_3[0]… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense_6 (Dense)               │ (None, 1, 1, 16)          │           2,064 │ reshape_6[0][0],           │
# │                               │                           │                 │ reshape_7[0][0]            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense_7 (Dense)               │ (None, 1, 1, 128)         │           2,176 │ dense_6[0][0],             │
# │                               │                           │                 │ dense_6[1][0]              │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ add_3 (Add)                   │ (None, 1, 1, 128)         │               0 │ dense_7[0][0],             │
# │                               │                           │                 │ dense_7[1][0]              │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ activation_3 (Activation)     │ (None, 1, 1, 128)         │               0 │ add_3[0][0]                │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ multiply_6 (Multiply)         │ (None, 32, 32, 128)       │               0 │ concatenate_3[0][0],       │
# │                               │                           │                 │ activation_3[0][0]         │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ lambda_6 (Lambda)             │ (None, 32, 32, 1)         │               0 │ multiply_6[0][0]           │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ lambda_7 (Lambda)             │ (None, 32, 32, 1)         │               0 │ multiply_6[0][0]           │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ concatenate_4 (Concatenate)   │ (None, 32, 32, 2)         │               0 │ lambda_6[0][0],            │
# │                               │                           │                 │ lambda_7[0][0]             │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_11 (Conv2D)            │ (None, 32, 32, 1)         │              99 │ concatenate_4[0][0]        │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ multiply_7 (Multiply)         │ (None, 32, 32, 128)       │               0 │ multiply_6[0][0],          │
# │                               │                           │                 │ conv2d_11[0][0]            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_transpose_2            │ (None, 32, 32, 64)        │          73,792 │ multiply_7[0][0]           │
# │ (Conv2DTranspose)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_10        │ (None, 32, 32, 64)        │             256 │ conv2d_transpose_2[0][0]   │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dropout_5 (Dropout)           │ (None, 32, 32, 64)        │               0 │ batch_normalization_10[0]… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_transpose_3            │ (None, 64, 64, 64)        │          36,928 │ dropout_5[0][0]            │
# │ (Conv2DTranspose)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_11        │ (None, 64, 64, 64)        │             256 │ conv2d_transpose_3[0][0]   │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ concatenate_5 (Concatenate)   │ (None, 64, 64, 96)        │               0 │ batch_normalization_11[0]… │
# │                               │                           │                 │ multiply_3[0][0]           │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ global_average_pooling2d_4    │ (None, 96)                │               0 │ concatenate_5[0][0]        │
# │ (GlobalAveragePooling2D)      │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ global_max_pooling2d_4        │ (None, 96)                │               0 │ concatenate_5[0][0]        │
# │ (GlobalMaxPooling2D)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ reshape_8 (Reshape)           │ (None, 1, 1, 96)          │               0 │ global_average_pooling2d_… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ reshape_9 (Reshape)           │ (None, 1, 1, 96)          │               0 │ global_max_pooling2d_4[0]… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense_8 (Dense)               │ (None, 1, 1, 12)          │           1,164 │ reshape_8[0][0],           │
# │                               │                           │                 │ reshape_9[0][0]            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense_9 (Dense)               │ (None, 1, 1, 96)          │           1,248 │ dense_8[0][0],             │
# │                               │                           │                 │ dense_8[1][0]              │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ add_4 (Add)                   │ (None, 1, 1, 96)          │               0 │ dense_9[0][0],             │
# │                               │                           │                 │ dense_9[1][0]              │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ activation_4 (Activation)     │ (None, 1, 1, 96)          │               0 │ add_4[0][0]                │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ multiply_8 (Multiply)         │ (None, 64, 64, 96)        │               0 │ concatenate_5[0][0],       │
# │                               │                           │                 │ activation_4[0][0]         │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ lambda_8 (Lambda)             │ (None, 64, 64, 1)         │               0 │ multiply_8[0][0]           │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ lambda_9 (Lambda)             │ (None, 64, 64, 1)         │               0 │ multiply_8[0][0]           │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ concatenate_6 (Concatenate)   │ (None, 64, 64, 2)         │               0 │ lambda_8[0][0],            │
# │                               │                           │                 │ lambda_9[0][0]             │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_12 (Conv2D)            │ (None, 64, 64, 1)         │              99 │ concatenate_6[0][0]        │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ multiply_9 (Multiply)         │ (None, 64, 64, 96)        │               0 │ multiply_8[0][0],          │
# │                               │                           │                 │ conv2d_12[0][0]            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_transpose_4            │ (None, 64, 64, 32)        │          27,680 │ multiply_9[0][0]           │
# │ (Conv2DTranspose)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_12        │ (None, 64, 64, 32)        │             128 │ conv2d_transpose_4[0][0]   │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dropout_6 (Dropout)           │ (None, 64, 64, 32)        │               0 │ batch_normalization_12[0]… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_transpose_5            │ (None, 128, 128, 32)      │           9,248 │ dropout_6[0][0]            │
# │ (Conv2DTranspose)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_13        │ (None, 128, 128, 32)      │             128 │ conv2d_transpose_5[0][0]   │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ concatenate_7 (Concatenate)   │ (None, 128, 128, 64)      │               0 │ batch_normalization_13[0]… │
# │                               │                           │                 │ multiply_1[0][0]           │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ global_average_pooling2d_5    │ (None, 64)                │               0 │ concatenate_7[0][0]        │
# │ (GlobalAveragePooling2D)      │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ global_max_pooling2d_5        │ (None, 64)                │               0 │ concatenate_7[0][0]        │
# │ (GlobalMaxPooling2D)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ reshape_10 (Reshape)          │ (None, 1, 1, 64)          │               0 │ global_average_pooling2d_… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ reshape_11 (Reshape)          │ (None, 1, 1, 64)          │               0 │ global_max_pooling2d_5[0]… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense_10 (Dense)              │ (None, 1, 1, 8)           │             520 │ reshape_10[0][0],          │
# │                               │                           │                 │ reshape_11[0][0]           │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense_11 (Dense)              │ (None, 1, 1, 64)          │             576 │ dense_10[0][0],            │
# │                               │                           │                 │ dense_10[1][0]             │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ add_5 (Add)                   │ (None, 1, 1, 64)          │               0 │ dense_11[0][0],            │
# │                               │                           │                 │ dense_11[1][0]             │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ activation_5 (Activation)     │ (None, 1, 1, 64)          │               0 │ add_5[0][0]                │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ multiply_10 (Multiply)        │ (None, 128, 128, 64)      │               0 │ concatenate_7[0][0],       │
# │                               │                           │                 │ activation_5[0][0]         │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ lambda_10 (Lambda)            │ (None, 128, 128, 1)       │               0 │ multiply_10[0][0]          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ lambda_11 (Lambda)            │ (None, 128, 128, 1)       │               0 │ multiply_10[0][0]          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ concatenate_8 (Concatenate)   │ (None, 128, 128, 2)       │               0 │ lambda_10[0][0],           │
# │                               │                           │                 │ lambda_11[0][0]            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_13 (Conv2D)            │ (None, 128, 128, 1)       │              99 │ concatenate_8[0][0]        │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ multiply_11 (Multiply)        │ (None, 128, 128, 64)      │               0 │ multiply_10[0][0],         │
# │                               │                           │                 │ conv2d_13[0][0]            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_transpose_6            │ (None, 128, 128, 32)      │          18,464 │ multiply_11[0][0]          │
# │ (Conv2DTranspose)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_14        │ (None, 128, 128, 32)      │             128 │ conv2d_transpose_6[0][0]   │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dropout_7 (Dropout)           │ (None, 128, 128, 32)      │               0 │ batch_normalization_14[0]… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_transpose_7            │ (None, 128, 128, 32)      │           9,248 │ dropout_7[0][0]            │
# │ (Conv2DTranspose)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_15        │ (None, 128, 128, 32)      │             128 │ conv2d_transpose_7[0][0]   │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_14 (Conv2D)            │ (None, 128, 128, 32)      │           1,056 │ batch_normalization_15[0]… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_16        │ (None, 128, 128, 32)      │             128 │ conv2d_14[0][0]            │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_15 (Conv2D)            │ (None, 128, 128, 32)      │           1,056 │ batch_normalization_16[0]… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_17        │ (None, 128, 128, 32)      │             128 │ conv2d_15[0][0]            │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_16 (Conv2D)            │ (None, 128, 128, 1)       │              33 │ batch_normalization_17[0]… │
# └───────────────────────────────┴───────────────────────────┴─────────────────┴────────────────────────────┘
#  Total params: 422,631 (1.61 MB)
#  Trainable params: 420,967 (1.61 MB)
#  Non-trainable params: 1,664 (6.50 KB)

# %%
# Callbacks and Save Best Model
checkpoint = ModelCheckpoint(
    filepath="best_model.keras",
    monitor="val_loss",
    save_best_only=True,
    verbose=1
)

early_stopping = EarlyStopping(
    monitor="val_loss",
    patience=50,
    restore_best_weights=True,
    verbose=1
)

# Train model
history = model.fit(
    train_xx, train_yy,
    validation_data=(test_xx, test_yy),
    epochs=100,
    batch_size=50,
    verbose=1,
    callbacks=[early_stopping, checkpoint]
)
# Out:
# Epoch 1/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.6411 - loss: 0.2252
# Epoch 1: val_loss improved from inf to 0.23697, saving model to best_model.keras
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 207s 4s/step - accuracy: 0.6428 - loss: 0.2242 - val_accuracy: 0.5150 - val_loss: 0.2370
# Epoch 2/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.8482 - loss: 0.1082
# Epoch 2: val_loss improved from 0.23697 to 0.21876, saving model to best_model.keras
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 191s 4s/step - accuracy: 0.8484 - loss: 0.1081 - val_accuracy: 0.5367 - val_loss: 0.2188
# Epoch 3/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.8781 - loss: 0.0889
# Epoch 3: val_loss improved from 0.21876 to 0.18524, saving model to best_model.keras
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 188s 4s/step - accuracy: 0.8781 - loss: 0.0889 - val_accuracy: 0.6633 - val_loss: 0.1852
# Epoch 4/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.8889 - loss: 0.0808
# Epoch 4: val_loss improved from 0.18524 to 0.17395, saving model to best_model.keras
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 187s 4s/step - accuracy: 0.8889 - loss: 0.0808 - val_accuracy: 0.6820 - val_loss: 0.1740
# Epoch 5/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.8949 - loss: 0.0761
# Epoch 5: val_loss improved from 0.17395 to 0.16958, saving model to best_model.keras
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 186s 4s/step - accuracy: 0.8949 - loss: 0.0761 - val_accuracy: 0.7159 - val_loss: 0.1696
# Epoch 6/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.8957 - loss: 0.0748
# Epoch 6: val_loss improved from 0.16958 to 0.09321, saving model to best_model.keras
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 193s 4s/step - accuracy: 0.8957 - loss: 0.0748 - val_accuracy: 0.8751 - val_loss: 0.0932
# Epoch 7/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.9037 - loss: 0.0697
# Epoch 7: val_loss improved from 0.09321 to 0.07768, saving model to best_model.keras
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 187s 4s/step - accuracy: 0.9036 - loss: 0.0697 - val_accuracy: 0.8910 - val_loss: 0.0777
# Epoch 8/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.9082 - loss: 0.0662
# Epoch 8: val_loss did not improve from 0.07768
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 188s 4s/step - accuracy: 0.9082 - loss: 0.0662 - val_accuracy: 0.8810 - val_loss: 0.0859
# Epoch 9/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.9081 - loss: 0.0661
# Epoch 9: val_loss did not improve from 0.07768
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 188s 4s/step - accuracy: 0.9081 - loss: 0.0661 - val_accuracy: 0.8652 - val_loss: 0.0968
# Epoch 10/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.9132 - loss: 0.0626
# Epoch 10: val_loss improved from 0.07768 to 0.07559, saving model to best_model.keras
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 187s 4s/step - accuracy: 0.9133 - loss: 0.0626 - val_accuracy: 0.8960 - val_loss: 0.0756
# Epoch 11/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.9142 - loss: 0.0624
# Epoch 11: val_loss improved from 0.07559 to 0.06654, saving model to best_model.keras
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 188s 4s/step - accuracy: 0.9142 - loss: 0.0624 - val_accuracy: 0.9096 - val_loss: 0.0665
# Epoch 12/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.9157 - loss: 0.0608
# Epoch 12: val_loss did not improve from 0.06654
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 188s 4s/step - accuracy: 0.9158 - loss: 0.0608 - val_accuracy: 0.8975 - val_loss: 0.0755
# Epoch 13/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.9218 - loss: 0.0568
# Epoch 13: val_loss did not improve from 0.06654
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 188s 4s/step - accuracy: 0.9218 - loss: 0.0568 - val_accuracy: 0.9058 - val_loss: 0.0679
# Epoch 14/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.9200 - loss: 0.0584
# Epoch 14: val_loss did not improve from 0.06654
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 189s 4s/step - accuracy: 0.9200 - loss: 0.0584 - val_accuracy: 0.8563 - val_loss: 0.1065
# Epoch 15/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.9242 - loss: 0.0551
# Epoch 15: val_loss did not improve from 0.06654
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 187s 4s/step - accuracy: 0.9242 - loss: 0.0551 - val_accuracy: 0.8880 - val_loss: 0.0867
# Epoch 16/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.9277 - loss: 0.0528
# Epoch 16: val_loss did not improve from 0.06654
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 190s 4s/step - accuracy: 0.9277 - loss: 0.0529 - val_accuracy: 0.8879 - val_loss: 0.0823
# Epoch 17/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.9280 - loss: 0.0525
# Epoch 17: val_loss did not improve from 0.06654
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 187s 4s/step - accuracy: 0.9280 - loss: 0.0526 - val_accuracy: 0.9073 - val_loss: 0.0677
# Epoch 18/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.9245 - loss: 0.0552
# Epoch 18: val_loss improved from 0.06654 to 0.06306, saving model to best_model.keras
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 188s 4s/step - accuracy: 0.9245 - loss: 0.0552 - val_accuracy: 0.9144 - val_loss: 0.0631
# Epoch 19/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.9278 - loss: 0.0529
# Epoch 19: val_loss did not improve from 0.06306
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 188s 4s/step - accuracy: 0.9277 - loss: 0.0529 - val_accuracy: 0.9141 - val_loss: 0.0648
# Epoch 20/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.9302 - loss: 0.0510
# Epoch 20: val_loss did not improve from 0.06306
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 187s 4s/step - accuracy: 0.9302 - loss: 0.0510 - val_accuracy: 0.9074 - val_loss: 0.0697
# Epoch 21/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.9229 - loss: 0.0560
# Epoch 21: val_loss did not improve from 0.06306
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 189s 4s/step - accuracy: 0.9230 - loss: 0.0559 - val_accuracy: 0.8932 - val_loss: 0.0785
# Epoch 22/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.9309 - loss: 0.0505
# Epoch 22: val_loss did not improve from 0.06306
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 187s 4s/step - accuracy: 0.9310 - loss: 0.0504 - val_accuracy: 0.9120 - val_loss: 0.0654
# Epoch 23/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.9356 - loss: 0.0473
# Epoch 23: val_loss did not improve from 0.06306
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 187s 4s/step - accuracy: 0.9356 - loss: 0.0473 - val_accuracy: 0.9064 - val_loss: 0.0682
# Epoch 24/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.9352 - loss: 0.0475
# Epoch 24: val_loss did not improve from 0.06306
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 191s 4s/step - accuracy: 0.9352 - loss: 0.0476 - val_accuracy: 0.8720 - val_loss: 0.1022
# Epoch 25/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.9353 - loss: 0.0476
# Epoch 25: val_loss did not improve from 0.06306
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 189s 4s/step - accuracy: 0.9353 - loss: 0.0476 - val_accuracy: 0.9021 - val_loss: 0.0723
# Epoch 26/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.9366 - loss: 0.0465
# Epoch 26: val_loss did not improve from 0.06306
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 187s 4s/step - accuracy: 0.9366 - loss: 0.0465 - val_accuracy: 0.9064 - val_loss: 0.0695
# Epoch 27/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.9401 - loss: 0.0441
# Epoch 27: val_loss did not improve from 0.06306
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 187s 4s/step - accuracy: 0.9401 - loss: 0.0442 - val_accuracy: 0.9097 - val_loss: 0.0661
# Epoch 28/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.9387 - loss: 0.0451
# Epoch 28: val_loss did not improve from 0.06306
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 187s 4s/step - accuracy: 0.9387 - loss: 0.0451 - val_accuracy: 0.9031 - val_loss: 0.0711
# Epoch 29/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.9406 - loss: 0.0438
# Epoch 29: val_loss did not improve from 0.06306
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 186s 4s/step - accuracy: 0.9405 - loss: 0.0438 - val_accuracy: 0.9048 - val_loss: 0.0713
# Epoch 30/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.9397 - loss: 0.0445
# Epoch 30: val_loss did not improve from 0.06306
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 187s 4s/step - accuracy: 0.9396 - loss: 0.0445 - val_accuracy: 0.9087 - val_loss: 0.0672
# Epoch 31/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.9414 - loss: 0.0431
# Epoch 31: val_loss did not improve from 0.06306
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 186s 4s/step - accuracy: 0.9414 - loss: 0.0431 - val_accuracy: 0.9016 - val_loss: 0.0719
# Epoch 32/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.9408 - loss: 0.0436
# Epoch 32: val_loss did not improve from 0.06306
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 187s 4s/step - accuracy: 0.9408 - loss: 0.0435 - val_accuracy: 0.9011 - val_loss: 0.0735
# Epoch 33/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.9418 - loss: 0.0426
# Epoch 33: val_loss did not improve from 0.06306
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 186s 4s/step - accuracy: 0.9418 - loss: 0.0426 - val_accuracy: 0.9134 - val_loss: 0.0654
# Epoch 34/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.9438 - loss: 0.0415
# Epoch 34: val_loss did not improve from 0.06306
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 187s 4s/step - accuracy: 0.9437 - loss: 0.0415 - val_accuracy: 0.9051 - val_loss: 0.0720
# Epoch 35/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.9440 - loss: 0.0415
# Epoch 35: val_loss did not improve from 0.06306
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 188s 4s/step - accuracy: 0.9440 - loss: 0.0415 - val_accuracy: 0.9103 - val_loss: 0.0675
# Epoch 36/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.9440 - loss: 0.0413
# Epoch 36: val_loss did not improve from 0.06306
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 187s 4s/step - accuracy: 0.9441 - loss: 0.0413 - val_accuracy: 0.9041 - val_loss: 0.0727
# Epoch 37/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.9446 - loss: 0.0409
# Epoch 37: val_loss did not improve from 0.06306
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 188s 4s/step - accuracy: 0.9446 - loss: 0.0409 - val_accuracy: 0.9126 - val_loss: 0.0654
# Epoch 38/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.9482 - loss: 0.0383
# Epoch 38: val_loss did not improve from 0.06306
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 188s 4s/step - accuracy: 0.9482 - loss: 0.0383 - val_accuracy: 0.8965 - val_loss: 0.0784
# Epoch 39/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.9422 - loss: 0.0428
# Epoch 39: val_loss did not improve from 0.06306
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 186s 4s/step - accuracy: 0.9422 - loss: 0.0428 - val_accuracy: 0.9044 - val_loss: 0.0719
# Epoch 40/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.9472 - loss: 0.0391
# Epoch 40: val_loss did not improve from 0.06306
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 187s 4s/step - accuracy: 0.9472 - loss: 0.0391 - val_accuracy: 0.8724 - val_loss: 0.0988
# Epoch 41/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.9476 - loss: 0.0388
# Epoch 41: val_loss did not improve from 0.06306
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 187s 4s/step - accuracy: 0.9476 - loss: 0.0388 - val_accuracy: 0.9107 - val_loss: 0.0675
# Epoch 42/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.9471 - loss: 0.0389
# Epoch 42: val_loss improved from 0.06306 to 0.05890, saving model to best_model.keras
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 187s 4s/step - accuracy: 0.9471 - loss: 0.0389 - val_accuracy: 0.9208 - val_loss: 0.0589
# Epoch 43/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.9511 - loss: 0.0361
# Epoch 43: val_loss did not improve from 0.05890
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 187s 4s/step - accuracy: 0.9511 - loss: 0.0361 - val_accuracy: 0.9086 - val_loss: 0.0703
# Epoch 44/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.9515 - loss: 0.0359
# Epoch 44: val_loss did not improve from 0.05890
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 191s 4s/step - accuracy: 0.9515 - loss: 0.0359 - val_accuracy: 0.9189 - val_loss: 0.0610
# Epoch 45/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.9466 - loss: 0.0393
# Epoch 45: val_loss did not improve from 0.05890
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 188s 4s/step - accuracy: 0.9467 - loss: 0.0393 - val_accuracy: 0.9080 - val_loss: 0.0689
# Epoch 46/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.9494 - loss: 0.0372
# Epoch 46: val_loss did not improve from 0.05890
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 188s 4s/step - accuracy: 0.9494 - loss: 0.0372 - val_accuracy: 0.8712 - val_loss: 0.0999
# Epoch 47/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.9529 - loss: 0.0349
# Epoch 47: val_loss did not improve from 0.05890
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 187s 4s/step - accuracy: 0.9529 - loss: 0.0349 - val_accuracy: 0.9101 - val_loss: 0.0692
# Epoch 48/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.9511 - loss: 0.0360
# Epoch 48: val_loss did not improve from 0.05890
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 187s 4s/step - accuracy: 0.9512 - loss: 0.0360 - val_accuracy: 0.9063 - val_loss: 0.0715
# Epoch 49/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.9529 - loss: 0.0348
# Epoch 49: val_loss did not improve from 0.05890
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 187s 4s/step - accuracy: 0.9529 - loss: 0.0348 - val_accuracy: 0.9108 - val_loss: 0.0684
# Epoch 50/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.9523 - loss: 0.0353
# Epoch 50: val_loss did not improve from 0.05890
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 187s 4s/step - accuracy: 0.9523 - loss: 0.0353 - val_accuracy: 0.9207 - val_loss: 0.0611
# Epoch 51/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.9540 - loss: 0.0341
# Epoch 51: val_loss did not improve from 0.05890
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 187s 4s/step - accuracy: 0.9539 - loss: 0.0341 - val_accuracy: 0.9150 - val_loss: 0.0646
# Epoch 52/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.9524 - loss: 0.0351
# Epoch 52: val_loss did not improve from 0.05890
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 187s 4s/step - accuracy: 0.9524 - loss: 0.0351 - val_accuracy: 0.9174 - val_loss: 0.0631
# Epoch 53/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.9524 - loss: 0.0353
# Epoch 53: val_loss did not improve from 0.05890
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 187s 4s/step - accuracy: 0.9524 - loss: 0.0353 - val_accuracy: 0.9200 - val_loss: 0.0600
# Epoch 54/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.9532 - loss: 0.0346
# Epoch 54: val_loss did not improve from 0.05890
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 188s 4s/step - accuracy: 0.9532 - loss: 0.0346 - val_accuracy: 0.9082 - val_loss: 0.0708
# Epoch 55/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.9550 - loss: 0.0333
# Epoch 55: val_loss did not improve from 0.05890
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 187s 4s/step - accuracy: 0.9550 - loss: 0.0333 - val_accuracy: 0.9065 - val_loss: 0.0710
# Epoch 56/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.9562 - loss: 0.0324
# Epoch 56: val_loss did not improve from 0.05890
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 188s 4s/step - accuracy: 0.9562 - loss: 0.0324 - val_accuracy: 0.9055 - val_loss: 0.0742
# Epoch 57/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.9554 - loss: 0.0330
# Epoch 57: val_loss did not improve from 0.05890
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 187s 4s/step - accuracy: 0.9554 - loss: 0.0330 - val_accuracy: 0.9113 - val_loss: 0.0672
# Epoch 58/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.9556 - loss: 0.0329
# Epoch 58: val_loss did not improve from 0.05890
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 187s 4s/step - accuracy: 0.9556 - loss: 0.0329 - val_accuracy: 0.9110 - val_loss: 0.0677
# Epoch 59/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.9571 - loss: 0.0317
# Epoch 59: val_loss did not improve from 0.05890
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 187s 4s/step - accuracy: 0.9571 - loss: 0.0317 - val_accuracy: 0.9124 - val_loss: 0.0683
# Epoch 60/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.9562 - loss: 0.0323
# Epoch 60: val_loss did not improve from 0.05890
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 186s 4s/step - accuracy: 0.9562 - loss: 0.0323 - val_accuracy: 0.8908 - val_loss: 0.0863
# Epoch 61/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.9579 - loss: 0.0312
# Epoch 61: val_loss did not improve from 0.05890
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 187s 4s/step - accuracy: 0.9578 - loss: 0.0312 - val_accuracy: 0.9038 - val_loss: 0.0748
# Epoch 62/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.9570 - loss: 0.0318
# Epoch 62: val_loss did not improve from 0.05890
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 187s 4s/step - accuracy: 0.9570 - loss: 0.0318 - val_accuracy: 0.9216 - val_loss: 0.0593
# Epoch 63/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.9568 - loss: 0.0320
# Epoch 63: val_loss did not improve from 0.05890
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 190s 4s/step - accuracy: 0.9568 - loss: 0.0320 - val_accuracy: 0.9194 - val_loss: 0.0622
# Epoch 64/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.9585 - loss: 0.0307
# Epoch 64: val_loss did not improve from 0.05890
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 187s 4s/step - accuracy: 0.9585 - loss: 0.0307 - val_accuracy: 0.9008 - val_loss: 0.0780
# Epoch 65/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.9572 - loss: 0.0316
# Epoch 65: val_loss did not improve from 0.05890
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 186s 4s/step - accuracy: 0.9572 - loss: 0.0316 - val_accuracy: 0.9194 - val_loss: 0.0611
# Epoch 66/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.9574 - loss: 0.0315
# Epoch 66: val_loss did not improve from 0.05890
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 186s 4s/step - accuracy: 0.9574 - loss: 0.0315 - val_accuracy: 0.9165 - val_loss: 0.0654
# Epoch 67/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.9596 - loss: 0.0299
# Epoch 67: val_loss did not improve from 0.05890
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 187s 4s/step - accuracy: 0.9596 - loss: 0.0300 - val_accuracy: 0.9202 - val_loss: 0.0605
# Epoch 68/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.9565 - loss: 0.0321
# Epoch 68: val_loss did not improve from 0.05890
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 186s 4s/step - accuracy: 0.9565 - loss: 0.0321 - val_accuracy: 0.9136 - val_loss: 0.0680
# Epoch 69/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.9592 - loss: 0.0301
# Epoch 69: val_loss did not improve from 0.05890
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 186s 4s/step - accuracy: 0.9592 - loss: 0.0302 - val_accuracy: 0.8788 - val_loss: 0.0978
# Epoch 70/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.9592 - loss: 0.0302
# Epoch 70: val_loss did not improve from 0.05890
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 187s 4s/step - accuracy: 0.9592 - loss: 0.0302 - val_accuracy: 0.8944 - val_loss: 0.0820
# Epoch 71/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.9598 - loss: 0.0298
# Epoch 71: val_loss did not improve from 0.05890
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 186s 4s/step - accuracy: 0.9599 - loss: 0.0297 - val_accuracy: 0.9078 - val_loss: 0.0719
# Epoch 72/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.9576 - loss: 0.0314
# Epoch 72: val_loss did not improve from 0.05890
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 188s 4s/step - accuracy: 0.9576 - loss: 0.0314 - val_accuracy: 0.9063 - val_loss: 0.0709
# Epoch 73/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.9607 - loss: 0.0290
# Epoch 73: val_loss did not improve from 0.05890
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 188s 4s/step - accuracy: 0.9607 - loss: 0.0290 - val_accuracy: 0.9101 - val_loss: 0.0704
# Epoch 74/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.9605 - loss: 0.0292
# Epoch 74: val_loss did not improve from 0.05890
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 186s 4s/step - accuracy: 0.9605 - loss: 0.0292 - val_accuracy: 0.9145 - val_loss: 0.0658
# Epoch 75/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.9612 - loss: 0.0287
# Epoch 75: val_loss did not improve from 0.05890
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 187s 4s/step - accuracy: 0.9611 - loss: 0.0287 - val_accuracy: 0.9136 - val_loss: 0.0665
# Epoch 76/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.9597 - loss: 0.0298
# Epoch 76: val_loss did not improve from 0.05890
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 187s 4s/step - accuracy: 0.9597 - loss: 0.0298 - val_accuracy: 0.9098 - val_loss: 0.0688
# Epoch 77/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.9606 - loss: 0.0292
# Epoch 77: val_loss did not improve from 0.05890
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 187s 4s/step - accuracy: 0.9606 - loss: 0.0292 - val_accuracy: 0.9173 - val_loss: 0.0635
# Epoch 78/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.9613 - loss: 0.0286
# Epoch 78: val_loss did not improve from 0.05890
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 186s 4s/step - accuracy: 0.9612 - loss: 0.0286 - val_accuracy: 0.8967 - val_loss: 0.0805
# Epoch 79/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.9624 - loss: 0.0278
# Epoch 79: val_loss did not improve from 0.05890
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 186s 4s/step - accuracy: 0.9624 - loss: 0.0278 - val_accuracy: 0.9171 - val_loss: 0.0642
# Epoch 80/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.9618 - loss: 0.0282
# Epoch 80: val_loss did not improve from 0.05890
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 187s 4s/step - accuracy: 0.9618 - loss: 0.0282 - val_accuracy: 0.9123 - val_loss: 0.0686
# Epoch 81/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.9615 - loss: 0.0285
# Epoch 81: val_loss did not improve from 0.05890
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 187s 4s/step - accuracy: 0.9615 - loss: 0.0285 - val_accuracy: 0.9129 - val_loss: 0.0671
# Epoch 82/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.9619 - loss: 0.0282
# Epoch 82: val_loss did not improve from 0.05890
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 188s 4s/step - accuracy: 0.9619 - loss: 0.0282 - val_accuracy: 0.9156 - val_loss: 0.0653
# Epoch 83/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.9614 - loss: 0.0286
# Epoch 83: val_loss did not improve from 0.05890
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 190s 4s/step - accuracy: 0.9614 - loss: 0.0286 - val_accuracy: 0.9161 - val_loss: 0.0664
# Epoch 84/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.9605 - loss: 0.0291
# Epoch 84: val_loss did not improve from 0.05890
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 187s 4s/step - accuracy: 0.9605 - loss: 0.0291 - val_accuracy: 0.8933 - val_loss: 0.0848
# Epoch 85/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.9618 - loss: 0.0282
# Epoch 85: val_loss did not improve from 0.05890
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 186s 4s/step - accuracy: 0.9618 - loss: 0.0282 - val_accuracy: 0.9120 - val_loss: 0.0682
# Epoch 86/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.9627 - loss: 0.0275
# Epoch 86: val_loss did not improve from 0.05890
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 187s 4s/step - accuracy: 0.9627 - loss: 0.0275 - val_accuracy: 0.9175 - val_loss: 0.0635
# Epoch 87/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.9621 - loss: 0.0280
# Epoch 87: val_loss did not improve from 0.05890
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 186s 4s/step - accuracy: 0.9621 - loss: 0.0280 - val_accuracy: 0.9148 - val_loss: 0.0664
# Epoch 88/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.9642 - loss: 0.0265
# Epoch 88: val_loss did not improve from 0.05890
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 186s 4s/step - accuracy: 0.9642 - loss: 0.0265 - val_accuracy: 0.9173 - val_loss: 0.0645
# Epoch 89/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.9637 - loss: 0.0268
# Epoch 89: val_loss did not improve from 0.05890
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 186s 4s/step - accuracy: 0.9637 - loss: 0.0268 - val_accuracy: 0.8964 - val_loss: 0.0826
# Epoch 90/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.9611 - loss: 0.0287
# Epoch 90: val_loss did not improve from 0.05890
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 187s 4s/step - accuracy: 0.9611 - loss: 0.0287 - val_accuracy: 0.9174 - val_loss: 0.0651
# Epoch 91/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.9640 - loss: 0.0266
# Epoch 91: val_loss did not improve from 0.05890
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 187s 4s/step - accuracy: 0.9640 - loss: 0.0266 - val_accuracy: 0.9221 - val_loss: 0.0610
# Epoch 92/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.9640 - loss: 0.0266
# Epoch 92: val_loss did not improve from 0.05890
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 186s 4s/step - accuracy: 0.9640 - loss: 0.0266 - val_accuracy: 0.8894 - val_loss: 0.0889
# Epoch 92: early stopping
# Restoring model weights from the end of the best epoch: 42.

# %%
# Plot training & validation loss
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

# Plot training & validation accuracy
plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

plt.show()

# %% [markdown]
# # **Prediction**

# %%
from tensorflow.keras.models import load_model
import tensorflow as tf

model = load_model("best_model.keras", safe_mode=False)

# %%
# Threshold for binary classification
threshold = 0.3

# Prediction of the output
pred_test = model.predict(test_xx)
pred_test = (pred_test > threshold).astype(np.uint8)
print(pred_test.shape)

# Plot the images horizontally with titles
plt.figure(figsize=(15, 5))

# Prediction
plt.subplot(1, 2, 1)
plt.imshow(pred_test[15, :, :, 0])
plt.title("Prediction")
plt.axis('off')

# Ground Truth
plt.subplot(1, 2, 2)
plt.imshow(test_yy[15,:,:,0])
plt.title("Ground Truth")
plt.axis('off')

# Display the plots
plt.tight_layout()
plt.show()
# Out:
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 725ms/step
# (80, 128, 128, 1)

# %% [markdown]
# ## **Convert numpy array to image**

# %%
# !pip install rasterio
# Out:
# Requirement already satisfied: rasterio in d:\anaconda\lib\site-packages (1.4.3)
# [notice] A new release of pip is available: 24.0 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: affine in d:\anaconda\lib\site-packages (from rasterio) (2.4.0)
# Requirement already satisfied: attrs in d:\anaconda\lib\site-packages (from rasterio) (21.4.0)
# Requirement already satisfied: certifi in d:\anaconda\lib\site-packages (from rasterio) (2022.9.14)
# Requirement already satisfied: click>=4.0 in d:\anaconda\lib\site-packages (from rasterio) (8.0.4)
# Requirement already satisfied: cligj>=0.5 in d:\anaconda\lib\site-packages (from rasterio) (0.7.2)
# Requirement already satisfied: importlib-metadata in d:\anaconda\lib\site-packages (from rasterio) (4.11.3)
# Requirement already satisfied: numpy>=1.24 in d:\anaconda\lib\site-packages (from rasterio) (1.26.4)
# Requirement already satisfied: click-plugins in d:\anaconda\lib\site-packages (from rasterio) (1.1.1.2)
# Requirement already satisfied: pyparsing in d:\anaconda\lib\site-packages (from rasterio) (3.0.9)
# Requirement already satisfied: colorama in d:\anaconda\lib\site-packages (from click>=4.0->rasterio) (0.4.5)
# Requirement already satisfied: zipp>=0.5 in d:\anaconda\lib\site-packages (from importlib-metadata->rasterio) (3.8.0)

# %%
import rasterio
from rasterio.transform import from_origin
import numpy as np
import os

# Define the output folder for predictions
output_folder = r"D:\Kuliah\Magister\Tesis\Percobaan\CBAM3\output"
os.makedirs(output_folder, exist_ok=True)

def save_prediction_with_coordinates(pred_array, input_paths, out_folder):
    """
    Save predictions with the same coordinate system and metadata as input images.

    Args:
        pred_array: Numpy array of predictions (n, h, w, 1).
        input_paths: List of paths to input images (georeferenced).
        out_folder: Folder to save the output predictions.
    """
    for i, input_path in enumerate(input_paths):
        # Open the corresponding input image to read its metadata
        with rasterio.open(input_path) as src:
            profile = src.profile  # Copy the metadata
            profile.update({
                "dtype": "uint8",  # Update data type for binary predictions
                "count": 1,        # Single-band output
                "compress": "lzw"  # Optional: compression
            })
            output_path = os.path.join(out_folder, f"{i}_prediction.tif")

            # Save the prediction with the same georeferencing information
            with rasterio.open(output_path, "w", **profile) as dst:
                dst.write(pred_array[i, :, :, 0].astype("uint8"), 1)

# Save predictions with georeferencing
save_prediction_with_coordinates(pred_test, test_x, output_folder)

# %%
import rasterio
from rasterio.merge import merge
import glob
import os

def merge_predictions(output_folder, merged_output_path):
    """
    Merge all georeferenced prediction tiles into a single raster.

    Args:
        output_folder: Folder containing individual prediction tiles.
        merged_output_path: Path to save the merged raster.
    """
    # Find all GeoTIFF files in the output folder
    tile_paths = sorted(glob.glob(os.path.join(output_folder, "*.tif")))

    # Open all the tiles
    src_files_to_mosaic = []
    for tile_path in tile_paths:
        src = rasterio.open(tile_path)
        src_files_to_mosaic.append(src)

    # Merge tiles
    mosaic, out_transform = merge(src_files_to_mosaic)

    # Use the metadata of the first tile as a base
    out_meta = src_files_to_mosaic[0].meta.copy()
    out_meta.update({
        "driver": "GTiff",
        "height": mosaic.shape[1],
        "width": mosaic.shape[2],
        "transform": out_transform,
        "count": 1  # Single band
    })

    # Save the merged raster
    with rasterio.open(merged_output_path, "w", **out_meta) as dest:
        dest.write(mosaic[0], 1)

    # Close all opened tiles
    for src in src_files_to_mosaic:
        src.close()

# Folder containing prediction tiles
output_folder = r"D:\Kuliah\Magister\Tesis\Percobaan\CBAM3\output"

# Path to save the merged raster
merged_output_path = r"D:\Kuliah\Magister\Tesis\Percobaan\CBAM3\output\merged_prediction.tif"

# Merge prediction tiles
merge_predictions(output_folder, merged_output_path)

print(f"Merged raster saved at {merged_output_path}")
# Out:
# Merged raster saved at D:\Kuliah\Magister\Tesis\Percobaan\CBAM3\output\merged_prediction.tif

# %% [markdown]
# ## **Accuracy assessment**
#
# In image segmentation, the overall model accuracy is determined by following metrics,
#
# 1. Precision
# 2. recall
# 3. F1-Score
# 4. Intersection over Union (IoU)
#
# ![image.png](data:image/png;base64,...)
#
#
# ![image.png](data:image/png;base64,...)

# %%
test_yy = test_yy.astype('uint8')
pred_test = pred_test.astype('uint8')

# %%
def calculate_metrics(ground_truth, predicted_mask):
    # Flatten the binary masks to 1D arrays
    ground_truth = ground_truth.ravel()
    predicted_mask = predicted_mask.ravel()

    # True Positives, False Positives, False Negatives
    TP = np.sum((ground_truth == 1) & (predicted_mask == 1))
    FP = np.sum((ground_truth == 0) & (predicted_mask == 1))
    FN = np.sum((ground_truth == 1) & (predicted_mask == 0))

    # True Negatives (optional, may not be needed for all cases)
    TN = np.sum((ground_truth == 0) & (predicted_mask == 0))

    # Calculate Precision, Recall, and F1 Score
    precision = TP / (TP + FP)
    recall = TP / (TP + FN)
    f1_score = 2 * (precision * recall) / (precision + recall)

    # Calculate Intersection over Union (IoU)
    iou = TP / (TP + FP + FN)

    # Calculate Overall Accuracy
    oa = (TP + TN) / (TP + TN + FP + FN)

    return precision, recall, f1_score, iou, oa

# %%
print(calculate_metrics(test_yy, pred_test))
# Out:
# (0.8873551819846951, 0.9547698213584016, 0.9198289443413892, 0.8515585929865, 0.9159835815429688)
